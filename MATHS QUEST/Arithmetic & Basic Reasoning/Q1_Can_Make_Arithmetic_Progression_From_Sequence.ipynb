# %% [markdown]
# **Q1. Can Make Arithmetic Progression From Sequence**

# %% [markdown]
# - A sequence of numbers is called an arithmetic progression if the difference between any two consecutive elements is the same.
#
# - Given an array of numbers arr, return "***true***" if the array can be rearranged to form an arithmetic progression. Otherwise, return "***false***".

# %% [markdown]
# <p><strong class="example">Example 1:</strong></p>
#
# <pre><strong>Input:</strong> arr = [1,2,4]
# <strong>Output:</strong> false
# <strong>Explanation: </strong>There is no way to reorder the elements to obtain an arithmetic progression.
# </pre>
#
# <p><strong class="example">Example 2:</strong></p>
#
# <pre><strong>Input:</strong> arr = [3,5,1]
# <strong>Output:</strong> true
# <strong>Explanation: </strong>We can reorder the elements as [1,3,5] or [5,3,1] with differences 2 and -2 respectively, between each consecutive elements.
# </pre>

# %% [markdown]
# <br>
# <br>
# <br>

# %% [markdown]
# <p><strong class="example">Solution :</strong></p>

# %%
class Solution(object):
    def canMakeArithmeticProgression(self, arr):
        flag = False
        if len(arr) == 2:
            flag = True
        elif len(arr) >= 2:
            sarr = sorted(arr)
            diff = sarr[1] - sarr[0]
            for i in range(1, len(sarr) - 1):
                if (sarr[i + 1] - sarr[i]) == diff:
                    flag = True
                elif (sarr[i + 1] - sarr[i]) != diff:
                    flag = False
                    break
        return flag

# %%
obj = Solution()
arr1 = [1,10,10,10,19]
arr2 = [3,5,1,7]
arr3 = [0,1]
arr4 = [100, 200, 300, 400]
arr5 = [1, 2, 4]
arr6 = [244, 352, 271, 163, 433, 1, 406, 190, 28, 325, 109, 460, 55, 487, 217, 379, 136, 82, 298]

# %%
arrays = [arr1, arr2, arr3, arr4, arr5, arr6]

for arr in arrays:
    print(sorted(arr) , " :", end=" ")
    print(obj.canMakeArithmeticProgression(arr))
# Out:
# [1, 10, 10, 10, 19]  : False
# [1, 3, 5, 7]  : True
# [0, 1]  : True
# [100, 200, 300, 400]  : True
# [1, 2, 4]  : False
# [1, 28, 55, 82, 109, 136, 163, 190, 217, 244, 271, 298, 325, 352, 379, 406, 433, 460, 487]  : True

# %% [markdown]
# <br><br><br>

# %% [markdown]
# <p><strong class="example">Normal Explanation, step by step flow :</strong></p>

# %%
def canMakeArithmeticProgression(arr):
    flag = False
    if len(arr) == 2:
        flag = True
        print(flag)
    elif len(arr) >= 2:
        sarr = sorted(arr)
        diff = sarr[1] - sarr[0]
        print("diff = ",diff)
        for i in range(1, len(sarr) - 1):
            if (sarr[i + 1] - sarr[i]) == diff:
                print("sarr[i]",sarr[i + 1] - sarr[i])
                flag = True
            elif (sarr[i + 1] - sarr[i]) != diff:
                print("sarr[i]",sarr[i + 1] - sarr[i])
                flag = False
                break
    return print("Is it Sequence ? ",flag)

# %%
canMakeArithmeticProgression(arr1)
print("\n\n ----- \n\n")
canMakeArithmeticProgression(arr2)
print("\n\n ----- \n\n")
canMakeArithmeticProgression(arr3)
print("\n\n ----- \n\n")
canMakeArithmeticProgression(arr4)
print("\n\n ----- \n\n")
canMakeArithmeticProgression(arr5)
print("\n\n ----- \n\n")
canMakeArithmeticProgression(arr6)
print("\n\n ----- \n\n")
# Out:
# diff =  9
# sarr[i] 0
# Is it Sequence ?  False
#
#
#  -----
#
#
# diff =  2
# sarr[i] 2
# sarr[i] 2
# Is it Sequence ?  True
#
#
#  -----
#
#
# True
# Is it Sequence ?  True
#
#
#  -----
#
#
# diff =  100
# sarr[i] 100
# sarr[i] 100
# Is it Sequence ?  True
#
#
#  -----
#
#
# diff =  1
# sarr[i] 2
# Is it Sequence ?  False
#
#
#  -----
#
#
# diff =  27
# sarr[i] 27
# sarr[i] 27
# sarr[i] 27
# sarr[i] 27
# sarr[i] 27
# sarr[i] 27
# sarr[i] 27
# sarr[i] 27
# sarr[i] 27
# sarr[i] 27
# sarr[i] 27
# sarr[i] 27
# sarr[i] 27
# sarr[i] 27
# sarr[i] 27
# sarr[i] 27
# sarr[i] 27
# Is it Sequence ?  True
#
#
#  -----
